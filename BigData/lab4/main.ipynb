# %%
from indexer import index
from pagerank_mapreduce import pagerank_mapreduce
from pagerank_pregel import pagerank_pregel
from search import search_daat, search_taat

# %%
def print_ranks(ranks, label, docs):
    print(f"\n=== PageRank ({label}) ===")
    for doc_id, score in sorted(ranks.items(), key=lambda x: x[1], reverse=True):
        info = docs.get(doc_id, {})
        print(f"{score:.4f}  [{doc_id}] {info.get('title', '')} -> {info.get('url', '')}")

# %%
index()

#PageRank через MapReduce
mr_ranks = pagerank_mapreduce()

#PageRank через Pregel
pr_ranks = pagerank_pregel()

from search import load_index
_, _, _, docs = load_index()

print_ranks(mr_ranks, "MapReduce", docs)
print_ranks(pr_ranks, "Pregel", docs)

# %%
# 4. Полнотекстовый поиск
while True:
    q = input("\nВведите запрос (пусто для выхода): ").strip()
    if not q:
        break

    taat_res, docs = search_taat(q)
    daat_res, _ = search_daat(q)

    print(q)
    print("\n-- TAAT --")
    for doc_id, score in taat_res:
        info = docs[doc_id]
        print(f"{score:.4f}  {info['title']} -> {info['url']}")

    print("\n-- DAAT --")
    for doc_id, score in daat_res:
        info = docs[doc_id]
        print(f"{score:.4f}  {info['title']} -> {info['url']}")
# Out:
# Локвуд
#
# -- TAAT --
# 0.0134  Агентство «Локвуд и компания» -> https://ru.wikipedia.org/wiki/Агентство_«Локвуд_и_компания»
# 0.0104  Страуд, Джонатан -> https://ru.wikipedia.org/wiki/Страуд,_Джонатан
#
# -- DAAT --
# 0.0134  Агентство «Локвуд и компания» -> https://ru.wikipedia.org/wiki/Агентство_«Локвуд_и_компания»
# 0.0104  Страуд, Джонатан -> https://ru.wikipedia.org/wiki/Страуд,_Джонатан
# Сериал
#
# -- TAAT --
# 0.0022  Сверхъестественное (телесериал) -> https://ru.wikipedia.org/wiki/Сверхъестественное_(телесериал)
# 0.0021  Агентство «Локвуд и компания» -> https://ru.wikipedia.org/wiki/Агентство_«Локвуд_и_компания»
# 0.0019  Рик и Морти -> https://ru.wikipedia.org/wiki/Рик_и_Морти
#
# -- DAAT --
# 0.0022  Сверхъестественное (телесериал) -> https://ru.wikipedia.org/wiki/Сверхъестественное_(телесериал)
# 0.0021  Агентство «Локвуд и компания» -> https://ru.wikipedia.org/wiki/Агентство_«Локвуд_и_компания»
# 0.0019  Рик и Морти -> https://ru.wikipedia.org/wiki/Рик_и_Морти
# Сэм  Дин Винчестеры
#
# -- TAAT --
# 0.0195  Сверхъестественное (телесериал) -> https://ru.wikipedia.org/wiki/Сверхъестественное_(телесериал)
#
# -- DAAT --
# 0.0195  Сверхъестественное (телесериал) -> https://ru.wikipedia.org/wiki/Сверхъестественное_(телесериал)
# Призрак
#
# -- TAAT --
# 0.0108  Привидение -> https://ru.wikipedia.org/wiki/Привидение
#
# -- DAAT --
# 0.0108  Привидение -> https://ru.wikipedia.org/wiki/Привидение
# Призраки
#
# -- TAAT --
# 0.0034  Агентство «Локвуд и компания» -> https://ru.wikipedia.org/wiki/Агентство_«Локвуд_и_компания»
# 0.0011  Привидение -> https://ru.wikipedia.org/wiki/Привидение
#
# -- DAAT --
# 0.0034  Агентство «Локвуд и компания» -> https://ru.wikipedia.org/wiki/Агентство_«Локвуд_и_компания»
# 0.0011  Привидение -> https://ru.wikipedia.org/wiki/Привидение
# ученый
#
# -- TAAT --
#
# -- DAAT --
# безумный ученый
#
# -- TAAT --
#
# -- DAAT --
# внук Рика
#
# -- TAAT --
# 0.0151  Рик и Морти -> https://ru.wikipedia.org/wiki/Рик_и_Морти
#
# -- DAAT --
# 0.0000  Рик и Морти -> https://ru.wikipedia.org/wiki/Рик_и_Морти
# Путешествия Рик Морти
#
# -- TAAT --
# 0.0179  Рик и Морти -> https://ru.wikipedia.org/wiki/Рик_и_Морти
# 0.0003  Сверхъестественное (телесериал) -> https://ru.wikipedia.org/wiki/Сверхъестественное_(телесериал)
#
# -- DAAT --
# 0.0179  Рик и Морти -> https://ru.wikipedia.org/wiki/Рик_и_Морти
# 0.0003  Сверхъестественное (телесериал) -> https://ru.wikipedia.org/wiki/Сверхъестественное_(телесериал)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 4. Полнотекстовый поиск
#       2 while True:
# ----> 3     q = input("\nВведите запрос (пусто для выхода): ").strip()
#       4     if not q:
#       5         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
